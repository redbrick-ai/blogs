# %%
import pydicom
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 200

# %%
instance = pydicom.dcmread("volume/000011.dcm")
pixel_array = instance.pixel_array
plt.imshow(pixel_array, cmap="gray")

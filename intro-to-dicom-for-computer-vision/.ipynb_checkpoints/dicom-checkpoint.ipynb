# %%
import pydicom
import os
import numpy as np

# %% [markdown]
# ## Read in files from disk

# %%
dir = "harvard-chest-ct/98.12.2"
files = os.listdir(dir)

instances = [pydicom.dcmread(os.path.join(dir, file)) for file in files]
print("Number of instances:", len(instances))
# Out:
# Number of instances: 427

# %%
print(instances[0])
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 210
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.320298050811801098832515646773789048894
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.9590.100.1.3.100.9.4
# (0002, 0013) Implementation Version Name         SH: 'MATLAB IPT 9.4'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELICAL']
# (0008, 0012) Instance Creation Date              DA: '20200311'
# (0008, 0013) Instance Creation Time              TM: '113914.171'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.320298050811801098832515646773789048894
# (0008, 0020) Study Date                          DA: ''
# (0008, 0022) Acquisition Date                    DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0032) Acquisition Time                    TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0081) Institution Address                 ST: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: ''
# (0008, 1030) Study Description                   LO: 'LUNG'
# (0008, 103e) Series Description                  LO: 'Lung 1.5'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: ''
# (0010, 0010) Patient's Name                      PN: ''
# (0010, 0020) Patient ID                          LO: '98.12.21'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: '0.0'
# (0010, 1030) Patient's Weight                    DS: '0.0'
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0022) Scan Options                        CS: 'HELICAL'
# (0018, 0050) Slice Thickness                     DS: '1.5'
# (0018, 0060) KVP                                 DS: '120.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: ''
# (0018, 1030) Protocol Name                       LO: 'Chest Helcal'
# (0018, 1050) Spatial Resolution                  DS: '0.33'
# (0018, 1100) Reconstruction Diameter             DS: '423.0'
# (0018, 1110) Distance Source to Detector         DS: '1040.0'
# (0018, 1111) Distance Source to Patient          DS: '570.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '377.3'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '9528'
# (0018, 1151) X-Ray Tube Current                  IS: '82'
# (0018, 1152) Exposure                            IS: '62'
# (0018, 1160) Filter Type                         SH: 'SB'
# (0018, 1210) Convolution Kernel                  SH: 'SB'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.156.14702.1.1000.16.0.20200311113603875
# (0020, 000e) Series Instance UID                 UI: 1.2.156.14702.1.1000.16.1.2020031111365293700020003
# (0020, 0010) Study ID                            SH: '93725'
# (0020, 0011) Series Number                       IS: '4'
# (0020, 0012) Acquisition Number                  IS: '2'
# (0020, 0013) Instance Number                     IS: '131'
# (0020, 0032) Image Position (Patient)            DS: [-192, -211.5, -709.200012]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.2.156.14702.1.1000.16.3.20200311113603953
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '709.2'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.826172, 0.826172]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3307
# (0028, 1050) Window Center                       DS: '-500.0'
# (0028, 1051) Window Width                        DS: '1400.0'
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %%
print("Element name:", instances[0][0x0020, 0x000e].name)
print("Element tag:", instances[0][0x0020, 0x000e].tag)
print("Element VR:", instances[0][0x0020, 0x000e].VR)
print("Element Value:", instances[0][0x0020, 0x000e].value)
print("----")
print("Element name:", instances[0][0x0020, 0x0010].name)
print("Element tag:", instances[0][0x0020, 0x0010].tag)
print("Element VR:", instances[0][0x0020, 0x0010].VR)
print("Element Value:", instances[0][0x0020, 0x0010].value)
# Out:
# Element name: Series Instance UID
# Element tag: (0020, 000e)
# Element VR: UI
# Element Value: 1.2.156.14702.1.1000.16.1.2020031111365293700020003
# ----
# Element name: Study ID
# Element tag: (0020, 0010)
# Element VR: SH
# Element Value: 93725

# %%
dicom_dataset = {}
for instance in instances:
    if instance.StudyID not in dicom_dataset:
        # new study
        dicom_dataset[instance.StudyID] = {}
        
    if instance.StudyID in dicom_dataset:
        # part of existing study
        
        if instance.SeriesInstanceUID in dicom_dataset[instance.StudyID]:
            # part of existing series
            dicom_dataset[instance.StudyID][instance.SeriesInstanceUID] += [instance]
        else:
            # new series
            dicom_dataset[instance.StudyID][instance.SeriesInstanceUID] = [instance]

# %%
print("List of Studies:", list(dicom_dataset.keys()))
print("List of Series:", list(dicom_dataset["93725"].keys()))
# Out:
# List of Studies: ['93725']
# List of Series: ['1.2.156.14702.1.1000.16.1.2020031111365293700020003', '1.2.156.14702.1.1000.16.1.2020031111365289000020001', '1.2.156.14702.1.1000.16.1.2020031111365295300020004', '1.2.156.14702.1.1000.16.1.2020031111365290600020002', '1.2.156.14702.1.1000.16.1.2020031111360523400010001', '1.2.156.14702.1.1000.16.1.20200311114023234000110001']

# %% [markdown]
# ## Pixel Data

# %%
print(instance.PhotometricInterpretation)
# Out:
# MONOCHROME2

# %%
print(instance.PixelData)
# Out:
# b'3\x00\x15\x00\x05\x00b\x00\x14\x00\x00\x00\x01\x00\t\x00\'\x00.\x00\x1a\x00\x1b\x00(\x00%\x008\x00/\x00\x00\x00\x00\x00%\x00!\x00\t\x00\x15\x00 \x002\x00!\x006\x00\x1c\x00\x08\x00\x1c\x00\x1d\x00(\x00)\x00\x14\x00\t\x00\x12\x00\x14\x006\x00*\x00\x11\x00\x00\x00\x02\x00;\x00;\x00\x17\x00\x1e\x00\x00\x00\x11\x00\x1f\x00\x18\x00\x07\x009\x00H\x00.\x00!\x00\x17\x00!\x00\x1c\x00\x00\x00\x10\x00!\x006\x00\x00\x00\x00\x00\t\x007\x00"\x00\x00\x00\x1b\x00;\x00\x1f\x00/\x00#\x00\x15\x00\x18\x00\x17\x00"\x00&\x00*\x00\x00\x00\x0e\x00/\x004\x00<\x00\x02\x00\x08\x00\x1b\x00\x13\x002\x00\n\x00\x0e\x00\r\x005\x00\x03\x00\x00\x00\x00\x00\x18\x00.\x00\x00\x00 \x00\x0e\x00B\x00>\x00/\x00\x00\x00\x1c\x00-\x00\x18\x00 \x00\x00\x00\x15\x00\x03\x00\x1a\x00\t\x00F\x00\x15\x00#\x00\x17\x00\x16\x00\x07\x00$\x00:\x00\x13\x00\x02\x00&\x00\x1d\x00\x07\x00\x04\x00\x14\x00&\x00\x00\x00\x1c\x00Q\x00M\x00\x14\x00\x00\x00\x0f\x00\x1c\x00 \x00/\x00\x1d\x00\x03\x00\x03\x00#\x00\x17\x00\x16\x00\t\x00\x0c\x00%\x002\x00&\x00\x12\x00\x00\x00\x08\x00-\x00\x00\x00\n\x00B\x000\x00\x10\x00/\x00\n\x00$\x00\x00\x00\x00\x00\x0f\x009\x00\x08\x00-\x004\x00\x16\x00&\x00@\x00\x1d\x00\x00\x00\x02\x00\x1b\x00\x00\x00\x00\x00,\x00)\x00<\x00\x05\x00(\x00\x10\x00\x00\x005\x00\x00\x00\x1b\x00\x1f\x00(\x00"\x00\x04\x00\x18\x00\x15\x00-\x00\x1e\x00\x04\x00:\x00%\x00\x08\x00\x1d\x00/\x00\x00\x00\x0f\x00=\x008\x00\x03\x00\x00\x00\x14\x00\x18\x00%\x00.\x00\x1f\x00\x00\x00*\x00\x1d\x00\x04\x00)\x00\x19\x00\x18\x00\x01\x00\x16\x00\x1d\x00\x12\x00\x00\x00\x00\x00*\x00(\x00\x08\x00T\x00\x1f\x00\x00\x00\x0e\x00$\x00-\x00P\x00\n\x00\x00\x00\x00\x00:\x00Q\x00\x13\x00\n\x00\x00\x00%\x00=\x00\x14\x00\r\x00\x00\x00\x00\x00(\x00\x05\x00.\x00:\x00"\x00/\x00\r\x00\x00\x00/\x00:\x00\x16\x00\x08\x00\x18\x00\x00\x00\x03\x00O\x00&\x00\x14\x00\x00\x00\x00\x00\x0e\x00 \x00-\x00\x11\x00 \x009\x00\x00\x00\x10\x00\x14\x00!\x00\x12\x00"\x00\x10\x00\x1b\x00\x0b\x00\x05\x00\x17\x00\x00\x00E\x00\x1c\x00(\x00\x00\x00\x00\x00O\x00\x16\x00\x00\x00\x06\x00\x00\x004\x00-\x00.\x00&\x00\x1d\x00\x00\x00,\x00#\x00-\x00\x02\x00\x1f\x00.\x00\t\x00*\x00\x1f\x00\x1c\x00+\x00 \x00 \x00\x0c\x00\x13\x00\x10\x00\x10\x00\x12\x00\x10\x00\x1e\x00\x1a\x00V\x ...

# %%
print("The pixel array:", instance.pixel_array)
print("Unique values in the pixel array:", np.unique(instance.pixel_array))
# Out:
# [[25 25 25 ... 25 25 25]
#  [25 25 25 ... 25 25 25]
#  [25 25 25 ... 25 25 25]
#  ...
#  [25 25 25 ... 25 25 25]
#  [25 25 25 ... 25 25 25]
#  [25 25 25 ... 25 25 25]]
# [   0    1    2 ... 3641 3703 3761]
